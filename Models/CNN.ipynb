# %%
# Importing necessary libraries
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('reliance.csv')

# Create a new dataframe with only the 'Close' column
data = df.filter(['Close'])

# Convert the dataframe to a numpy array
dataset = data.values

# Scale the data to be values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1)) 
scaled_data = scaler.fit_transform(dataset)

# Define the training data length
training_data_len = math.ceil(len(dataset) * 0.7)

# Split the data into training and testing sets
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 30:, :]

# Split the data into x_train and y_train data sets
x_train = []
y_train = []
for i in range(30, len(train_data)):
    x_train.append(train_data[i-30:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data for CNN input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Define the CNN model
cnn_model = Sequential()

# Add the first convolutional layer
cnn_model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(x_train.shape[1], 1)))

# Add the max pooling layer
cnn_model.add(MaxPooling1D(pool_size=2))

# Add the flatten layer
cnn_model.add(Flatten())

# Add the first dense layer
cnn_model.add(Dense(units=50, activation='relu'))

# Add the second dense layer
cnn_model.add(Dense(units=50, activation='relu'))

# Add the output layer
cnn_model.add(Dense(units=1))

# Compile the model
cnn_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = cnn_model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# Reshape the test data
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(30, len(test_data)):
    x_test.append(test_data[i-30:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Predictions
cnn_predictions = cnn_model.predict(x_test)

# Rescale predictions
cnn_predictions = scaler.inverse_transform(cnn_predictions)

# Calculate RMSE
cnn_rmse = np.sqrt(np.mean((cnn_predictions - y_test)**2))

# Plot the predicted values against the original values
plt.figure(figsize=(14, 7))
plt.plot(y_test, label='Original')
plt.plot(cnn_predictions, label='Predicted')
plt.title('CNN Predictions vs Original Values')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

print("RMSE:", cnn_rmse)
# Out:
# Epoch 1/50
# 53/53 [==============================] - 3s 13ms/step - loss: 0.0389 - val_loss: 7.8492e-05
# Epoch 2/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 2.2077e-04
# Epoch 3/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 1.8623e-04
# Epoch 4/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 1.1759e-04
# Epoch 5/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 7.0312e-05
# Epoch 6/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 3.2323e-04
# Epoch 7/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 9.3596e-05
# Epoch 8/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 7.1203e-05
# Epoch 9/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 1.4274e-04
# Epoch 10/50
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 3.1001e-04
# Epoch 11/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 1.6198e-04
# Epoch 12/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 4.5834e-04
# Epoch 13/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 8.7523e-05
# Epoch 14/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 1.6863e-04
# Epoch 15/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.4805e-04 - val_loss: 1.6520e-04
# Epoch 16/50
# 53/53 [==============================] - 0s 7ms/step - loss: 9.3981e-04 - val_loss: 3.9897e-04
# Epoch 17/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.3130e-05
# Epoch 18/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.5885e-04 - val_loss: 1.2990e-04
# Epoch 19/50
# 53/53 [==============================] - 0s 7ms/step - loss: 9.9578e-04 - val_loss: 1.4387e-04
# Epoch 20/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 1.5512e-04
# Epoch 21/50
# 53/53 [==============================] - 0s 7ms/step - loss: 9.0008e-04 - val_loss: 2.1499e-04
# Epoch 22/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 1.8451e-04
# Epoch 23/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.8418e-04 - val_loss: 3.2956e-04
# Epoch 24/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.2742e-04 - val_loss: 3.2474e-04
# Epoch 25/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.0346e-04 - val_loss: 1.6169e-04
# Epoch 26/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.5134e-04 - val_loss: 1.6298e-04
# Epoch 27/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.9113e-04 - val_loss: 8.7580e-05
# Epoch 28/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.4889e-04 - val_loss: 1.3937e-04
# Epoch 29/50
# 53/53 [==============================] - 0s 8ms/step - loss: 8.8883e-04 - val_loss: 1.2334e-04
# Epoch 30/50
# 53/53 [==============================] - 0s 8ms/step - loss: 8.7024e-04 - val_loss: 9.8811e-05
# Epoch 31/50
# 53/53 [==============================] - 0s 7ms/step - loss: 9.0115e-04 - val_loss: 3.2605e-04
# Epoch 32/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.9283e-04 - val_loss: 1.4973e-04
# Epoch 33/50
# 53/53 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 2.6501e-04
# Epoch 34/50
# 53/53 [==============================] - 0s 7ms/step - loss: 8.5333e-04 - val_loss: 1.9194e-04
# Epoch 35/50
# 53/53 [==============================] - 0s 7ms/step - loss: 8.1523e-04 - val_loss: 1.2402e-04
# Epoch 36/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.5799e-04 - val_loss: 1.5640e-04
# Epoch 37/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.0583e-04 - val_loss: 2.2854e-04
# Epoch 38/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.5018e-04 - val_loss: 1.8251e-04
# Epoch 39/50
# 53/53 [==============================] - 0s 7ms/step - loss: 8.0955e-04 - val_loss: 8.4714e-05
# Epoch 40/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.1398e-04 - val_loss: 1.4424e-04
# Epoch 41/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.3511e-04 - val_loss: 1.1952e-04
# Epoch 42/50
# 53/53 [==============================] - 0s 7ms/step - loss: 8.2967e-04 - val_loss: 1.5129e-04
# Epoch 43/50
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 1.9717e-04
# Epoch 44/50
# 53/53 [==============================] - 0s 9ms/step - loss: 9.2406e-04 - val_loss: 2.6415e-04
# Epoch 45/50
# 53/53 [==============================] - 0s 8ms/step - loss: 8.2929e-04 - val_loss: 2.2133e-04
# Epoch 46/50
# 53/53 [==============================] - 0s 8ms/step - loss: 8.4438e-04 - val_loss: 2.2848e-04
# Epoch 47/50
# 53/53 [==============================] - 0s 8ms/step - loss: 8.5322e-04 - val_loss: 2.3793e-04
# Epoch 48/50
# 53/53 [==============================] - 0s 6ms/step - loss: 9.5317e-04 - val_loss: 1.8634e-04
# Epoch 49/50
# 53/53 [==============================] - 0s 6ms/step - loss: 7.6683e-04 - val_loss: 4.2257e-04
# Epoch 50/50
# 53/53 [==============================] - 0s 6ms/step - loss: 8.1679e-04 - val_loss: 9.7934e-05
# 26/26 [==============================] - 0s 4ms/step
# RMSE: 37.7407339329638
